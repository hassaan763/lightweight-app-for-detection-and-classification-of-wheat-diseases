# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# fatal: destination path 'stylegan2-ada-pytorch' already exists and is not an empty directory.

# %%
# %cd stylegan2-ada-pytorch/
# Out:
# /kaggle/working/stylegan2-ada-pytorch

# %%
# !mkdir results
# Out:
# mkdir: cannot create directory ‘results’: File exists

# %%
# !pip3 install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# ...
#      |████████████████████████████████| 717 kB 5.1 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 422 kB 53.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 26.9 MB 60.9 MB/s eta 0:00:01
# ...
#   Created wheel for pyspng: filename=pyspng-0.1.3-cp37-cp37m-linux_x86_64.whl size=155686 sha256=670aa63640ac1785e81427334226512f84237acf1ddc82a9d085680568b74f06
#   Stored in directory: /root/.cache/pip/wheels/21/f7/9d/33b781c08014cbcb0f61a6b726eb2667d5052bffeecf23dd8f
# Successfully built pyspng
# ...
# WARNING: You are using pip version 21.0.1; however, version 24.0 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
# !python dataset_tool.py \
  --source="/kaggle/input/wheat-dataset/Original_dataset/Brown Rust" \
  --dest="/kaggle/working/wheat_dataset.zip" \
  --width=512 \
  --height=512
# Out:
# 100%|███████████████████████████████████████| 1128/1128 [00:40<00:00, 27.79it/s]

# %%
# !python train.py \
  --gpus=2 \
  --snap=10 \
  --outdir=./results \
  --data=/kaggle/working/wheat_dataset.zip \
  --kimg=500 \
  --resume=/kaggle/input/test2/other/default/1/network-snapshot-0002000.pkl\
  --aug=ada \
  --mirror=1 \
  --cfg=auto\
  --metrics=none\
  --dry-run
# Out:
# Training options:
# {
#   "num_gpus": 2,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/kaggle/working/wheat_dataset.zip",
#     "use_labels": false,
#     "max_size": 1128,
#     "xflip": true,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...

# %%
# !python train.py \
  --gpus=2 \
  --snap=50 \
  --outdir=./results \
  --data=/kaggle/working/wheat_dataset.zip \
  --resume=/kaggle/input/test2/other/default/1/network-snapshot-0002000.pkl\
  --kimg=500 \
  --aug=ada \
  --mirror=1 \
  --cfg=auto\
  --metrics=fid50k_full,is50k
# Out:
# Training options:
# {
#   "num_gpus": 2,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "metrics": [
#     "fid50k_full",
#     "is50k"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/kaggle/working/wheat_dataset.zip",
#     "use_labels": false,
#     "max_size": 1128,
#     "xflip": true,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
# ...

# %%
# !zip -r results.zip ./results

# %%
# !ls /kaggle/input/flower-network/network-snapshot-000161.pkl

# %%
# !mkdir images

# %%
"""
import torch
from torchvision.utils import save_image
import pickle
import math

n_images = 60

with open('./results/00000-preprocessed-flowers-auto1-kimg161/network-snapshot-000161.pkl', 'rb') as f:
    G = pickle.load(f)['G_ema'].cuda()  # torch.nn.Module

for i in range(10):
    zs = torch.randn([n_images, G.z_dim]).cuda() 

    c = None                                # class labels (not used in this example)
    img = G(zs, c)                           # NCHW, float32, dynamic range [-1, +1]
    print(img.shape)
    save_image(img, f"images/image_{i}.png", nrow=30)
"""

# %%
# !zip -r images.zip images/
